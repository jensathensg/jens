# %% [markdown]
# <a href="https://colab.research.google.com/github/jensathensg/jens/blob/main/Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Part 2

advertising <- read.csv("Advertising - Advertising - Advertising - Advertising - Advertising - Advertising (1).csv")

head(advertising)

summary(advertising)

plot(advertising$TV,
     advertising$sales,
     main = "TV Advertising vs Sales",
     xlab = "TV Advertising",
     ylab = "Sales",
     col = "blue",
     pch = 19)

cor(advertising$TV, advertising$sales)
# Out:
#   TV    radio newspaper sales
# 1 230.1 37.8  69.2      22.1
# 2  44.5 39.3  45.1      10.4
# 3  17.2 45.9  69.3       9.3
# 4 151.5 41.3  58.5      18.5
# 5 180.8 10.8  58.4      12.9
# 6   8.7 48.9  75.0       7.2
#        TV             radio          newspaper          sales
#  Min.   :  0.70   Min.   : 0.000   Min.   :  0.30   Min.   : 1.60
#  1st Qu.: 74.38   1st Qu.: 9.975   1st Qu.: 12.75   1st Qu.:10.38
#  Median :149.75   Median :22.900   Median : 25.75   Median :12.90
#  Mean   :147.04   Mean   :23.264   Mean   : 30.55   Mean   :14.02
#  3rd Qu.:218.82   3rd Qu.:36.525   3rd Qu.: 45.10   3rd Qu.:17.40
#  Max.   :296.40   Max.   :49.600   Max.   :114.00   Max.   :27.00
# [1] 0.7822244
# Plot with title “TV Advertising vs Sales”
