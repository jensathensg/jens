# %% [markdown]
# <a href="https://colab.research.google.com/github/jensathensg/jens/blob/main/Part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Part 4

advertising$Predicted_Sales <- fitted(model)
advertising$Residual <- residuals(model)

head(advertising[, c("sales", "Predicted_Sales", "Residual")], 10)
# Out:
#    sales Predicted_Sales Residual
# 1  22.1  17.970775        4.1292255
# 2  10.4   9.147974        1.2520260
# 3   9.3   7.850224        1.4497762
# 4  18.5  14.234395        4.2656054
# 5  12.9  15.627218       -2.7272181
# 6   7.2   7.446162       -0.2461623
# 7  11.8   9.765950        2.0340496
# 8  13.2  12.746498        0.4535023
# 9   4.8   7.441409       -2.6414087
# 10 10.6  16.530414       -5.9304143
