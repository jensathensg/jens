# %% [markdown]
# <a href="https://colab.research.google.com/github/jensathensg/jens/blob/main/Part_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
advertising <- read.csv(
  "Advertising - Advertising - Advertising - Advertising - Advertising - Advertising (1).csv"
)

model <- lm(sales ~ TV, data = advertising)

summary(model)$sigma
# Out:
# [1] 3.258656
