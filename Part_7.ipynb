# %% [markdown]
# <a href="https://colab.research.google.com/github/jensathensg/jens/blob/main/Part_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
advertising <- read.csv("Advertising - Advertising - Advertising - Advertising - Advertising - Advertising (1).csv")

model <- lm(sales ~ TV, data = advertising)

y <- advertising$sales
yhat <- fitted(model)

TSS <- sum((y - mean(y))^2)
RSS <- sum((y - yhat)^2)
RegSS <- TSS - RSS

sums_of_squares <- data.frame(
  Measure = c("TSS", "RSS", "RegSS", "RegSS + RSS"),
  Value = round(c(TSS, RSS, RegSS, RegSS + RSS), 4)
)

print(sums_of_squares, row.names = FALSE)
# Out:
#      Measure    Value
#          TSS 5417.149
#          RSS 2102.531
#        RegSS 3314.618
#  RegSS + RSS 5417.149
